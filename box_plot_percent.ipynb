# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('./logs/wgan_new/csv/result_match.csv', sep=',', header=None)
# df_t = df.T
df.columns = df.iloc[0]
df /= 10
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 1])
plt.savefig("./figures/wgan_result_match.png", format="png", dpi=600)

# %%
df=pd.read_csv('./logs/wgan_new/csv/result_truth.csv', sep=',', header=None)
df.columns = df.iloc[0]
df /= 120
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 0.4])
plt.savefig("./figures/wgan_result_truth.png", format="png", dpi=600)

# %%
df=pd.read_csv('./logs/cgan_disc/csv/result_match.csv', sep=',', header=None)
# df_t = df.T
df.columns = df.iloc[0]
df /= 10
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 1])
plt.savefig("./figures/cgan_result_match.png", format="png", dpi=600)

# %%
df=pd.read_csv('./logs/cgan_disc/csv/result_truth.csv', sep=',', header=None)
df.columns = df.iloc[0]
df /= 120
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 0.4])
plt.savefig("./figures/cgan_result_truth.png", format="png", dpi=600)

# %%
df=pd.read_csv('./logs/server-weak-disc-30k/csv/result_match.csv', sep=',', header=None)
# df_t = df.T
df.columns = df.iloc[0]
df /= 10
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 1])
plt.savefig("./figures/controlgan_result_match.png", format="png", dpi=600)

# %%
df=pd.read_csv('./logs/server-weak-disc-30k/csv/result_truth.csv', sep=',', header=None)
df.columns = df.iloc[0]
df /= 120
df = df[1:]
boxplot = df.boxplot()
boxplot.set_xlabel('wavelength (nm)')
boxplot.set_ylabel('occurrences')
boxplot.set_ylim([0, 0.4])
plt.savefig("./figures/controlgan_result_truth.png", format="png", dpi=600)
